# %%
# %run main.py
# Out:
#   File "/Users/Gerty/Desktop/Large-Scale ML/Minibatching-and-Momentum/main.py", line 138
#     W = W-alpha*grad(Xs, Ys, gamma, W)
#                                       ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.pyplot as p
plt.plot(epochs, GD_train_err,'black', label='Algo 1')
plt.plot(epochs, Nesterov1_train_err,'blue', label='SGD Sequential Scan')
plt.plot(epochs, Nesterov2_train_err,'purple', label='SGD Minibatch')
plt.plot(epochs, algo4_tr_error,'red', label='SGD Minibatch Sequential Scan')
plt.legend(bbox_to_anchor=(0.96, 0.96), loc=0, borderaxespad=0.)
p.ylabel('$\%$ Error')
p.xlabel('Epochs')
#p.ylim(0.05, 0.3)  
p.suptitle("SGD Training Error with alpha=0.1")
p.savefig('algo1_train_error.png',dpi=800, bbox_inches='tight')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
algo1_te_error = []
algo2_te_error = []
algo3_te_error = []
algo4_te_error = []
epochs = arange(1, 11, 1)
for i in arange(0,99,10):  # 10 Ws per epoch
      W1 = algo1_Ws[i]
#     W2 = algo2_Ws[i]
#     W3 = algo3_Ws[i]
#     W4 = algo4_Ws[i]
      algo1_te_error.append(multinomial_logreg_error(Xs_te, Ys_te, W1))
#     algo2_te_error.append(multinomial_logreg_error(Xs_te, Ys_te, W2))
#     algo3_te_error.append(multinomial_logreg_error(Xs_te, Ys_te, W3))
#     algo4_te_error.append(multinomial_logreg_error(Xs_te, Ys_te, W4))
plt.plot(epochs, algo1_te_error, 'black', label='Algo 1')
# plt.plot(epochs, algo2_te_error, 'blue', label='SGD Sequential Scan')
# plt.plot(epochs, algo3_te_error, 'purple', label='SGD Minibatch')
# plt.plot(epochs, algo4_te_error, 'red', label='SGD Minibatch Sequential Scan')
plt.legend(bbox_to_anchor=(0.96, 0.96), loc=0, borderaxespad=0.)
p.ylabel('$\%$ Error')
p.xlabel('Epochs')
p.suptitle('SGD Test Error with alpha=0.1')
p.savefig('algo1_test_error.png',dpi=800, bbox_inches='tight')
